# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (500, 9)

# %%
df.drop(columns=['Serial No.'],inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %% [markdown]
# For an regression problem always use activation function as a linear for output layer

# %%
model = Sequential()
model.add(Dense(7,activation='relu',input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1,activation='linear'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120 (480.00 B)
#  Trainable params: 120 (480.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error',optimizer='Adam',metrics=['mse'])

# %%
history = model.fit(x_train_scaled,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2649 - mse: 0.2649 - val_loss: 0.2301 - val_mse: 0.2301
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1612 - mse: 0.1612 - val_loss: 0.1397 - val_mse: 0.1397
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0904 - mse: 0.0904 - val_loss: 0.0808 - val_mse: 0.0808
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0521 - mse: 0.0521 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0475 - val_mse: 0.0475
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0403 - val_mse: 0.0403
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0324 - mse: 0.0324 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0306 - mse: 0.0306 - val_loss: 0.0357 - val_mse: 0.0357
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0291 - mse: 0.0291 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0316 - val_mse: 0.0316
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0294 - val_mse: 0.0294
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0272 - val_mse: 0.0272
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0231 - mse: 0.0231 - val_loss: 0.0250 - val_mse: 0.0250
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0215 - mse: 0.0215 - val_loss: 0.0230 - val_mse: 0.0230
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0200 - mse: 0.0200 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169 - mse: 0.0169 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162 - mse: 0.0162 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156 - mse: 0.0156 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0151 - val_mse: 0.0151
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0143 - val_mse: 0.0143
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0136 - val_mse: 0.0136
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0127 - val_mse: 0.0127
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mse: 0.0070 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - mse: 0.0067 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0066 - val_mse: 0.0066
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0058 - val_mse: 0.0058
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0056 - val_mse: 0.0056

# %%
y_pred = model.predict(x_test_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred
# Out:
# array([[0.61596304],
#        [0.702451  ],
#        [0.8693    ],
#        [0.66289747],
#        [0.8106581 ],
#        [0.5972388 ],
#        [0.68659276],
#        [0.68117917],
#        [0.764243  ],
#        [0.69558793],
#        [0.7219065 ],
#        [0.5759078 ],
#        [0.74651575],
#        [0.75779134],
#        [0.74050564],
#        [0.9291621 ],
#        [0.60631377],
#        [0.7007705 ],
#        [0.8983906 ],
#        [0.64696807],
#        [0.539749  ],
#        [0.7969941 ],
#        [0.7867184 ],
#        [0.7196499 ],
#        [0.75701016],
#        [0.63241524],
#        [0.89842194],
#        [0.657383  ],
#        [0.8385674 ],
#        [0.69138664],
#        [0.60392374],
#        [0.7537111 ],
#        [0.6014483 ],
#        [0.89868826],
#        [0.54164064],
#        [0.7821674 ],
#        [0.603096  ],
#        [0.63688534],
#        [0.63569355],
#        [0.8896142 ],
#        [0.5551786 ],
#        [0.6793513 ],
#        [0.772274  ],
#        [0.9672287 ],
#        [0.7819946 ],
#        [0.47910583],
#        [0.54266834],
#        [0.57732594],
#        [0.6873515 ],
#        [0.64493406],
#        [0.82667196],
#        [0.9024687 ],
#        [0.87704587],
#        [0.61184996],
#        [0.6468735 ],
#        [0.6203076 ],
#        [0.7783975 ],
#        [0.6354345 ],
#        [0.6869644 ],
#        [0.71321183],
#        [0.4658445 ],
#        [0.6141097 ],
#        [0.708358  ],
#        [0.8309816 ],
#        [0.9472386 ],
#        [0.6371507 ],
#        [0.7272384 ],
#        [0.79556924],
#        [0.8561087 ],
#        [0.69591886],
#        [0.5988673 ],
#        [0.6025298 ],
#        [0.81107295],
#        [0.54304415],
#        [0.93339264],
#        [0.65720433],
#        [0.7986758 ],
#        [0.8820518 ],
#        [0.68233407],
#        [0.7760173 ],
#        [0.7817162 ],
#        [0.6340096 ],
#        [0.93630695],
#        [0.7638946 ],
#        [0.74682415],
#        [0.7359714 ],
#        [0.90801   ],
#        [0.9244217 ],
#        [0.57185596],
#        [0.6008679 ],
#        [0.6796153 ],
#        [0.6665963 ],
#        [0.5980327 ],
#        [0.74149317],
#        [0.8139116 ],
#        [0.8220339 ],
#        [0.8883514 ],
#        [0.5220521 ],
#        [0.7460192 ],
#        [0.7120594 ]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7170685264116248

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
